# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv",index_col='Date',parse_dates=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2019-09-09  21.230000  21.620001  21.160000  21.389999  21.074198   50200
# 2019-09-10  21.389999  22.330000  21.250000  21.900000  21.576668  102200
# 2019-09-11  21.969999  22.549999  21.969999  22.540001  22.207220   93000
# 2019-09-12  22.639999  22.850000  22.360001  22.450001  22.118549  131600
# 2019-09-13  22.650000  22.889999  22.480000  22.690001  22.355005   81000

# %%
df['Close'].plot()

# %%
df['Close'].plot()
df['Close'].rolling(window=15).mean().plot()
